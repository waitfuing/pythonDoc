# %%
import requests
url = 'https://www.***/accredited-employers-list'
res = requests.get(url).text
print(res)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8 ]><html lang="en" class="no-js ie ie8 ie9 all"><![endif]--><!--[if IE 9 ]><html lang="en" class="no-js ie ie9 all"><![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html xmlns="http://www.w3.org/1999/xhtml" lang="en" class="no-js all" xml:lang="en"><!--<![endif]-->
#
#
#
#
#
#   <head>
#
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#
#     <meta name="generator" content="Plone - http://plone.org" />
#
#
#       <!-- base tal:attributes="href plone_view/renderBase" /--><!--[if lt IE 7]></base><![endif]-->
#
#
#
#
# <!--[if IE 8 ]><html lang="en" class="no-js ie ie8 ie9 all"><![endif]-->
# <!--[if IE 9 ]><html lang="en" class="no-js ie ie9 all"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--><!--<![endif]-->
#
#
#
#
#     <meta charset="utf-8" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" /><!-- right at the top or it will be ignored, forces IE into the best mode /-->
#
#     <title>Accredited employers list | Immigration New Zealand</title>
#     <meta name="description" content="Use this tool to check if a New Zealand employer is accredited." />
#
#     <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=0" /><!-- controls page sizing and zooming on mobile devices /-->
#     <meta name="apple-mobile-web-app-title" content="Immigration New Zealand" /><!-- apple home screen title /-->
#     <meta name="application-name" content="Immigration New Zealand" /><!-- information for pinned sites: http://msdn.microsoft.com/en-nz/library/ie/gg491732%28v=vs.85%29.aspx /-->
#     <meta name="msapplication-tooltip" content="Immigration New Zealand" />
#
#     <link rel="icon" type="image/png" href="https://www.immigration.govt.nz/++resource++inz.static.27/favicon.ico" />
#     <meta name="msapplication-TileColor" content="#ffffff" />
#     <meta name="msapplication-TileImage" content="https://www.immigration.govt.nz/++resource++inz.static.27/icons/mstile-144x144.png" />
#
#
#         <link rel="canonical" href="https://www.immigration.govt.nz/new-zealand-visas/apply-for-a-visa/tools-and-information/tools/accredited-employers-list" />
#
#
#
#
#
#
#     <link rel="stylesheet" type="text/css" href="https://www.immigration.govt.nz/++resource++inz.static.27/production.min.css" />
#     <link rel="stylesheet" type="text/css" media="print" href="https://www.immigration.govt.nz/++resource++inz.static.27/print.css" />
#
#     <script type="text/javascript" src="/++resource++inz.site/modernizr.custom.min.js?r=cms-121.03"></script>
#
#
#     <link rel="stylesheet" type="text/css" href="https://www.immigration.govt.nz/css/cms-121.03/inz.css" />
#
#
#     <link rel="stylesheet" type="text/css" href="/++resource++inz.site/inz_icons/css/inz_icons.css?r=cms-121.03" />
#
#
#
#
#
#         <!--  link tal:replace="structure provider:plone.htmlhead.links" /-->
#
#
#
#
#
#
#
#
#
#
#
#
#         <!-- Tools API -->
#         <script type="text/javascript" src="https://www.immigration.govt.nz/js/cms-121.03/inz.tools.js"></script>
#
#         <!-- Instantiate Tool instance -->
#
#         <script type="text/javascript">
# var accredited_employers_registry_initialFields =
# [
#     {
#         "name": "industry",
#         "options": [
#             {
#                 "label": "Accounting, Finance & Legal",
#                 "value": "Accounting, Finance & Legal"
#             },
#             {
#                 "label": "Administration & Customer Service",
#                 "value": "Administration & Customer Service"
#             },
#             {
#                 "label": "Advertising, Media, PR",
#                 "value": "Advertising, Media, PR"
#             },
#             {
#                 "label": "Agriculture, Forestry and Fishing",
#                 "value": "Agriculture, Forestry and Fishing"
#             },
#             {
#                 "label": "Arts, Culture, Entertainers",
#                 "value": "Arts, Culture, Entertainers"
#             },
#             {
#                 "label": "Biotechnology",
#                 "value": "Biotechnology"
#             },
#             {
#                 "label": "Construction & Building",
#                 "value": "Construction & Building"
#             },
#             {
#                 "label": "Digital Media",
#                 "value": "Digital Media"
#             },
#             {
#                 "label": "Education & Training",
#                 "value": "Education & Training"
#             },
#             {
#                 "label": "Engineering",
#                 "value": "Engineering"
#             },
#             {
#                 "label": "Film & Television",
#                 "value": "Film & Television"
#             },
#             {
#                 "label": "Food and Beverages Manufacturing",
#                 "value": "Food and Beverages Manufacturing"
#             },
#             {
#                 "label": "Government (central)",
#                 "value": "Government (central)"
#             },
#             {
#                 "label": "Government (local)",
#                 "value": "Government (local)"
#             },
#             {
#                 "label": "Healthcare",
#                 "value": "Healthcare"
#             },
#             {
#                 "label": "High Value Manufacturing",
#                 "value": "High Value Manufacturing"
#             },
#             {
#                 "label": "Horticulture & Viticulture",
#                 "value": "Horticulture & Viticulture"
#             },
#             {
#                 "label": "Hospitality & Tourism",
#                 "value": "Hospitality & Tourism"
#             },
#             {
#                 "label": "Human Resources",
#                 "value": "Human Resources"
#             },
#             {
#                 "label": "Information Technology",
#                 "value": "Information Technology"
#             },
#             {
#                 "label": "Manufacturing",
#                 "value": "Manufacturing"
#             },
#             {
#                 "label": "Other",
#                 "value": "Other"
#             },
#             {
#                 "label": "Recruitment",
#                 "value": "Recruitment"
#             },
#             {
#                 "label": "Retail",
#                 "value": "Retail"
#             },
#             {
#                 "label": "Sales & Marketing",
#                 "value": "Sales & Marketing"
#             },
#             {
#                 "label": "Science & Technology",
#                 "value": "Science & Technology"
#             },
#             {
#                 "label": "Sports",
#                 "value": "Sports"
#             },
#             {
#                 "label": "Telecommunications",
#                 "value": "Telecommunications"
#             },
#             {
#                 "label": "Transport & Logistics",
#                 "value": "Transport & Logistics"
#             },
#             {
#                 "label": "Water, Gas, Electricity",
#                 "value": "Water, Gas, Electricity"
#             }
#         ],
#         "placeholder": "Industry or Sector",
#         "required": false,
#         "type": "select"
#     },
#     {
#         "name": "keywords",
#         "placeholder": "Keywords",
#         "required": false,
#         "type": "text"
#     }
# ];
#
# var accredited_employers_registry_searchConfig =
# [
#     {
#         "field": "industry",
#         "match": [
#             "secondary_data/@type=text/text"
#         ],
#         "type": "exact"
#     },
#     {
#         "field": "keywords",
#         "match": [
#             "title"
#         ],
#         "type": "fuzzy"
#     }
# ];
#
# var accredited_employers_registry_data =
# [
#     {
#         "id": "8i-limited",
#         "secondary_data": [
#             {
#                 "text": "Digital Media",
#                 "type": "text"
#             },
#             {
#                 "text": "www.8i.com",
#                 "type": "link",
#                 "url": "http://www.8i.com"
#             }
#         ],
#         "title": "8i Limited"
#     },
#     {
#         "id": "180-degrees-trust",
#         "secondary_data": [
#             {
#                 "text": "Education & Training",
#                 "type": "text"
#             },
#             {
#                 "text": "www.180degrees.org.nz",
#                 "type": "link",
#                 "url": "http://www.180degrees.org.nz"
#             }
#         ],
#         "title": "180 Degrees Trust"
#     },
#     {
#         "id": "a-r-finlayson-limited",
#         "secondary_data": [
#             {
#                 "text": "Agriculture, Forestry and Fishing",
#                 "type": "text"
#             }
#         ],
#         "title": "A & R Finlayson Limited"
#     },
#     {
#         "id": "a-1-collision-limited",
#         "secondary_data": [
#             {
#                 "text": "Other",
#                 "type": "text"
#             },
#             {
#                 "text": "www.a1autofinish.co.nz",
#                 "type": "link",
#                 "url": "http://www.a1autofinish.co.nz"
#             }
#         ],
#         "title": "A 1 Collision Limited"
#     },
#     {
#         "id": "a-and-t-van-maren",
#         "secondary_data": [
#             {
#                 "text": "Agriculture, Forestry and Fishing",
#                 "type": "text"
#             }
#         ],
#         "title": "A and T van Maren"
#     },
#     {
#         "id": "a-class-tree-services-limited",
#         "secondary_data": [
#             {
#                 "text": "Agriculture, Forestry and Fishing",
#                 "type": "text"
#             },
#             {
#                 "text": "aucklandtreeservices.nz",
#                 "type": "link",
#                 "url": "http://aucklandtreeservices.nz"
#             }
#         ],
#         "title": "A Class Tree Services Limited"
#     },
#     {
#         "id": "a-g-foley",
#         "secondary_data": [
#             {
#                 "text": "Water, Gas, Electricity",
#                 "type": "text"
#             },
#             {
#                 "text": "www.foleys.co.nz",
#                 "type": "link",
#                 "url": "http://www.foleys.co.nz/"
#             }
#         ],
#         "title": "A G Foley"
#     },
#     {
#         "id": "a-verkerk-limited",
#         "secondary_data": [
#             {
#                 "text": "Food and Beverages Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.verkerks.co.nz",
#                 "type": "link",
#                 "url": "http://www.verkerks.co.nz"
#             }
#         ],
#         "title": "A Verkerk Limited"
#     },
#     {
#         "id": "a-w-trinder-limited",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.trinder.co.nz",
#                 "type": "link",
#                 "url": "http://www.trinder.co.nz"
#             }
#         ],
#         "title": "A W Trinder Limited"
#     },
#     {
#         "id": "a-ward-limited",
#         "secondary_data": [
#             {
#                 "text": "Transport & Logistics",
#                 "type": "text"
#             },
#             {
#                 "text": "www.a-ward.com",
#                 "type": "link",
#                 "url": "http://www.a-ward.com"
#             }
#         ],
#         "title": "A-Ward Limited"
#     },
#     {
#         "id": "a-s-wilcox-sons-limited",
#         "secondary_data": [
#             {
#                 "text": "Agriculture, Forestry and Fishing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.wilcoxgoodness.co.nz",
#                 "type": "link",
#                 "url": "http://www.wilcoxgoodness.co.nz/"
#             }
#         ],
#         "title": "A.S. Wilcox & Sons Limited"
#     },
#     {
#         "id": "a1-kiwi-cutters-and-drillers-ltd",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.kiwicutters.co.nz",
#                 "type": "link",
#                 "url": "http://www.kiwicutters.co.nz/"
#             }
#         ],
#         "title": "A1 Kiwi Cutters and Drillers Ltd"
#     },
#     {
#         "id": "aa-insurance-limited",
#         "secondary_data": [
#             {
#                 "text": "Accounting, Finance & Legal",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aainsurance.co.nz",
#                 "type": "link",
#                 "url": "http://www.aainsurance.co.nz/"
#             }
#         ],
#         "title": "AA Insurance Limited"
#     },
#     {
#         "id": "aapc-properties-pty-limited-new-zealand-branch",
#         "secondary_data": [
#             {
#                 "text": "Hospitality & Tourism",
#                 "type": "text"
#             },
#             {
#                 "text": "www.accorhotels.com",
#                 "type": "link",
#                 "url": "http://www.accorhotels.com/"
#             }
#         ],
#         "title": "AAPC Properties Pty Limited - New Zealand Branch"
#     },
#     {
#         "id": "ab-equipment-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.abequipment.co.nz",
#                 "type": "link",
#                 "url": "http://www.abequipment.co.nz"
#             }
#         ],
#         "title": "AB Equipment Limited"
#     },
#     {
#         "id": "abb-limited",
#         "secondary_data": [
#             {
#                 "text": "Engineering",
#                 "type": "text"
#             },
#             {
#                 "text": "www.abb.co.nz",
#                 "type": "link",
#                 "url": "http://www.abb.co.nz/"
#             }
#         ],
#         "title": "ABB Limited"
#     },
#     {
#         "id": "abbotts-drainage-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.abbotts.co.nz",
#                 "type": "link",
#                 "url": "http://www.abbotts.co.nz/"
#             }
#         ],
#         "title": "Abbotts Drainage Limited"
#     },
#     {
#         "id": "abley-limited",
#         "secondary_data": [
#             {
#                 "text": "Engineering",
#                 "type": "text"
#             },
#             {
#                 "text": "www.abley.com",
#                 "type": "link",
#                 "url": "http://www.abley.com"
#             }
#         ],
#         "title": "Abley Limited"
#     },
#     {
#         "id": "absolute-it",
#         "secondary_data": [
#             {
#                 "text": "Human Resources",
#                 "type": "text"
#             },
#             {
#                 "text": "www.absoluteit.co.nz",
#                 "type": "link",
#                 "url": "http://www.absoluteit.co.nz/"
#             }
#         ],
#         "title": "Absolute IT"
#     },
#     {
#         "id": "accenture-nz-limited",
#         "secondary_data": [
#             {
#                 "text": "Information Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "www.accenture.co.nz",
#                 "type": "link",
#                 "url": "http://www.accenture.co.nz"
#             }
#         ],
#         "title": "Accenture NZ Limited"
#     },
#     {
#         "id": "access-solutions-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.accesssolutions.co.nz",
#                 "type": "link",
#                 "url": "http://www.accesssolutions.co.nz/"
#             }
#         ],
#         "title": "Access Solutions Limited"
#     },
#     {
#         "id": "acciona-infrastructure-new-zealand-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.acciona.com",
#                 "type": "link",
#                 "url": "http://www.acciona.com"
#             }
#         ],
#         "title": "Acciona Infrastructure New Zealand Limited"
#     },
#     {
#         "id": "academic-colleges-group",
#         "secondary_data": [
#             {
#                 "text": "Education & Training",
#                 "type": "text"
#             },
#             {
#                 "text": "www.acgedu.com",
#                 "type": "link",
#                 "url": "http://www.acgedu.com"
#             }
#         ],
#         "title": "ACG Schools"
#     },
#     {
#         "id": "aci-operations-nz-limited",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.o-i.com",
#                 "type": "link",
#                 "url": "http://www.o-i.com"
#             }
#         ],
#         "title": "ACI Operations NZ Limited"
#     },
#     {
#         "id": "acrow-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.acrow.co.nz",
#                 "type": "link",
#                 "url": "http://www.acrow.co.nz/"
#             }
#         ],
#         "title": "Acrow Limited"
#     },
#     {
#         "id": "active-contracting-2018-ltd",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.activecontracting.co.nz",
#                 "type": "link",
#                 "url": "http://www.activecontracting.co.nz/"
#             }
#         ],
#         "title": "Active Contracting 2018 Ltd"
#     },
#     {
#         "id": "adecco-personnel-limited",
#         "secondary_data": [
#             {
#                 "text": "Recruitment",
#                 "type": "text"
#             },
#             {
#                 "text": "www.adecco.co.nz",
#                 "type": "link",
#                 "url": "http://www.adecco.co.nz/"
#             }
#         ],
#         "title": "Adecco Personnel Limited"
#     },
#     {
#         "id": "adept-group-limited",
#         "secondary_data": [
#             {
#                 "text": "Information Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "www.adeptgroup.co.nz",
#                 "type": "link",
#                 "url": "http://www.adeptgroup.co.nz"
#             }
#         ],
#         "title": "Adept Group Limited"
#     },
#     {
#         "id": "adt-security-limited",
#         "secondary_data": [
#             {
#                 "text": "Other",
#                 "type": "text"
#             },
#             {
#                 "text": "www.adtsecurity.co.nz",
#                 "type": "link",
#                 "url": "http://www.adtsecurity.co.nz"
#             }
#         ],
#         "title": "ADT Security Limited"
#     },
#     {
#         "id": "advanced-security-group-sth-is-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.asgl.co.nz",
#                 "type": "link",
#                 "url": "http://www.asgl.co.nz/"
#             }
#         ],
#         "title": "Advanced Security Group (Sth Is)  Limited"
#     },
#     {
#         "id": "advanced-security-group-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.asgl.co.nz",
#                 "type": "link",
#                 "url": "http://www.asgl.co.nz"
#             }
#         ],
#         "title": "Advanced Security Group Limited"
#     },
#     {
#         "id": "aecom-new-zealand-limited",
#         "secondary_data": [
#             {
#                 "text": "Engineering",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aecom.com",
#                 "type": "link",
#                 "url": "http://www.aecom.com"
#             }
#         ],
#         "title": "AECOM New Zealand Limited"
#     },
#     {
#         "id": "aero-nz-2012-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aero.net.nz",
#                 "type": "link",
#                 "url": "http://www.aero.net.nz"
#             }
#         ],
#         "title": "Aero NZ (2012) Limited"
#     },
#     {
#         "id": "afc-group-holdings-limited",
#         "secondary_data": [
#             {
#                 "text": "Administration & Customer Service",
#                 "type": "text"
#             },
#             {
#                 "text": "www.afcnz.com",
#                 "type": "link",
#                 "url": "http://www.afcnz.com"
#             }
#         ],
#         "title": "AFC Group Holdings Limited"
#     },
#     {
#         "id": "affordable-granite-benchtops",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.agbstone.co.nz",
#                 "type": "link",
#                 "url": "http://www.agbstone.co.nz"
#             }
#         ],
#         "title": "Affordable Granite Benchtops"
#     },
#     {
#         "id": "affordable-scaffolding-2010-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.affordablescaffolding.co.nz",
#                 "type": "link",
#                 "url": "http://www.affordablescaffolding.co.nz/"
#             }
#         ],
#         "title": "Affordable Scaffolding (2010) Limited"
#     },
#     {
#         "id": "agc-networks-pte-limited",
#         "secondary_data": [
#             {
#                 "text": "Telecommunications",
#                 "type": "text"
#             },
#             {
#                 "text": "www.agcnetworks.com",
#                 "type": "link",
#                 "url": "http://www.agcnetworks.com/nz/"
#             }
#         ],
#         "title": "AGC Networks PTE Limited"
#     },
#     {
#         "id": "agility-cis-limited",
#         "secondary_data": [
#             {
#                 "text": "Information Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "www.agilitycis.com",
#                 "type": "link",
#                 "url": "http://www.agilitycis.com"
#             }
#         ],
#         "title": "Agility CIS Limited"
#     },
#     {
#         "id": "agilyx-nz-limited",
#         "secondary_data": [
#             {
#                 "text": "Information Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "www.agilyxgroup.co.nz",
#                 "type": "link",
#                 "url": "http://www.agilyxgroup.co.nz"
#             }
#         ],
#         "title": "Agilyx NZ Limited"
#     },
#     {
#         "id": "agnew-transport-services-limited",
#         "secondary_data": [
#             {
#                 "text": "Transport & Logistics",
#                 "type": "text"
#             },
#             {
#                 "text": "agnewtransport.co.nz",
#                 "type": "link",
#                 "url": "http://agnewtransport.co.nz/"
#             }
#         ],
#         "title": "Agnew Transport Services Limited"
#     },
#     {
#         "id": "agresearch-limited",
#         "secondary_data": [
#             {
#                 "text": "Agriculture, Forestry and Fishing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.agresearch.co.nz",
#                 "type": "link",
#                 "url": "http://www.agresearch.co.nz"
#             }
#         ],
#         "title": "AgResearch Limited"
#     },
#     {
#         "id": "aia-international-limited",
#         "secondary_data": [
#             {
#                 "text": "Accounting, Finance & Legal",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aia.co.nz",
#                 "type": "link",
#                 "url": "http://www.aia.co.nz"
#             }
#         ],
#         "title": "AIA International Limited"
#     },
#     {
#         "id": "aig-insurance-new-zealand",
#         "secondary_data": [
#             {
#                 "text": "Accounting, Finance & Legal",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aig.com",
#                 "type": "link",
#                 "url": "http://www.aig.com"
#             }
#         ],
#         "title": "AIG Insurance New Zealand"
#     },
#     {
#         "id": "aimex-limited",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aimex.co.nz",
#                 "type": "link",
#                 "url": "http://www.aimex.co.nz"
#             }
#         ],
#         "title": "Aimex Limited"
#     },
#     {
#         "id": "air-mark-services-limited",
#         "secondary_data": [
#             {
#                 "text": "Engineering",
#                 "type": "text"
#             },
#             {
#                 "text": "www.AirMarkGroup.co",
#                 "type": "link",
#                 "url": "http://www.AirMarkGroup.co"
#             }
#         ],
#         "title": "Air Mark Services Limited"
#     },
#     {
#         "id": "air-new-zealand-ltd",
#         "secondary_data": [
#             {
#                 "text": "Administration & Customer Service",
#                 "type": "text"
#             },
#             {
#                 "text": "www.airnewzealand.co.nz",
#                 "type": "link",
#                 "url": "http://www.airnewzealand.co.nz/"
#             }
#         ],
#         "title": "Air New Zealand Ltd"
#     },
#     {
#         "id": "airtight-solutions",
#         "secondary_data": [
#             {
#                 "text": "Science & Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "www.airtight.co.nz",
#                 "type": "link",
#                 "url": "http://www.airtight.co.nz"
#             }
#         ],
#         "title": "Airtight Solutions"
#     },
#     {
#         "id": "airways-corporation-of-new-zealand",
#         "secondary_data": [
#             {
#                 "text": "Government (central)",
#                 "type": "text"
#             },
#             {
#                 "text": "www.airways.co.nz",
#                 "type": "link",
#                 "url": "http://www.airways.co.nz/"
#             }
#         ],
#         "title": "Airways Corporation of New Zealand"
#     },
#     {
#         "id": "airwork-holdings-limited",
#         "secondary_data": [
#             {
#                 "text": "Engineering",
#                 "type": "text"
#             },
#             {
#                 "text": "www.airwork.co.nz",
#                 "type": "link",
#                 "url": "http://www.airwork.co.nz"
#             }
#         ],
#         "title": "Airwork Holdings Limited"
#     },
#     {
#         "id": "ajc-plumbing-gasfitting-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.mairangibay.laserplumbing.co.nz",
#                 "type": "link",
#                 "url": "http://www.mairangibay.laserplumbing.co.nz"
#             }
#         ],
#         "title": "AJC Plumbing & Gasfitting Limited"
#     },
#     {
#         "id": "alexander-construction-central-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "alexaderconstructioncentral.co.nz",
#                 "type": "link",
#                 "url": "http://alexaderconstructioncentral.co.nz"
#             }
#         ],
#         "title": "Alexander Construction Central Limited"
#     },
#     {
#         "id": "alexandra-asset-holdings-limited",
#         "secondary_data": [
#             {
#                 "text": "Retail",
#                 "type": "text"
#             },
#             {
#                 "text": "freshchoice.co.nz",
#                 "type": "link",
#                 "url": "https://freshchoice.co.nz/supermarkets/oxford"
#             }
#         ],
#         "title": "Alexandra Asset Holdings Limited"
#     },
#     {
#         "id": "all-euro-parts-limited",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.alleuroparts.co.nz",
#                 "type": "link",
#                 "url": "http://www.alleuroparts.co.nz"
#             }
#         ],
#         "title": "All Euro Parts Limited"
#     },
#     {
#         "id": "all-in-one-builders-company-ltd",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.allinonebuilders.co.nz",
#                 "type": "link",
#                 "url": "http://www.allinonebuilders.co.nz/"
#             }
#         ],
#         "title": "All in One Builders Company Ltd"
#     },
#     {
#         "id": "all-seasons-air-conditioning-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.allseasonsair.co.nz",
#                 "type": "link",
#                 "url": "http://www.allseasonsair.co.nz"
#             }
#         ],
#         "title": "All Seasons Air Conditioning Limited"
#     },
#     {
#         "id": "allan-sillick-co-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.advancedpumping.nz",
#                 "type": "link",
#                 "url": "http://www.advancedpumping.nz"
#             }
#         ],
#         "title": "Allan Sillick & Co Limited"
#     },
#     {
#         "id": "allegis-group-new-zealand-limited",
#         "secondary_data": [
#             {
#                 "text": "Human Resources",
#                 "type": "text"
#             },
#             {
#                 "text": "www.allegisgroup.com",
#                 "type": "link",
#                 "url": "http://www.allegisgroup.com/"
#             }
#         ],
#         "title": "Allegis Group New Zealand Limited"
#     },
#     {
#         "id": "allfields-customised-solutions-limited",
#         "secondary_data": [
#             {
#                 "text": "Information Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "allfields.co.nz",
#                 "type": "link",
#                 "url": "http://allfields.co.nz/"
#             }
#         ],
#         "title": "Allfields Customised Solutions Limited"
#     },
#     {
#         "id": "alliance-services-ltd",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.allianceservices.co.nz",
#                 "type": "link",
#                 "url": "http://www.allianceservices.co.nz"
#             }
#         ],
#         "title": "Alliance Services Ltd"
#     },
#     {
#         "id": "allied-petroleum-limited",
#         "secondary_data": [
#             {
#                 "text": "Water, Gas, Electricity",
#                 "type": "text"
#             },
#             {
#                 "text": "www.alliedpetroleum.co.nz",
#                 "type": "link",
#                 "url": "http://www.alliedpetroleum.co.nz"
#             }
#         ],
#         "title": "Allied Petroleum Limited"
#     },
#     {
#         "id": "alloy-cats-nz-limited",
#         "secondary_data": [
#             {
#                 "text": "High Value Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.alloycats.co.nz",
#                 "type": "link",
#                 "url": "http://www.alloycats.co.nz"
#             }
#         ],
#         "title": "Alloy Cats (NZ) Limited"
#     },
#     {
#         "id": "allstar-builders-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.allstarbuilder.co.nz",
#                 "type": "link",
#                 "url": "http://www.allstarbuilder.co.nz/"
#             }
#         ],
#         "title": "Allstar Builders Limited"
#     },
#     {
#         "id": "alpha-healthcare-new-zealand-limited",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "alphagroup.nz",
#                 "type": "link",
#                 "url": "http://alphagroup.nz/"
#             }
#         ],
#         "title": "Alpha Healthcare (New Zealand) Limited"
#     },
#     {
#         "id": "alpha-personnel-recruitment-limited",
#         "secondary_data": [
#             {
#                 "text": "Recruitment",
#                 "type": "text"
#             },
#             {
#                 "text": "www.alphajobs.co.nz",
#                 "type": "link",
#                 "url": "http://www.alphajobs.co.nz/"
#             }
#         ],
#         "title": "Alpha Personnel Recruitment Limited"
#     },
#     {
#         "id": "alpine-energy-limited",
#         "secondary_data": [
#             {
#                 "text": "Water, Gas, Electricity",
#                 "type": "text"
#             },
#             {
#                 "text": "www.alpineenergy.co.nz",
#                 "type": "link",
#                 "url": "http://www.alpineenergy.co.nz"
#             }
#         ],
#         "title": "Alpine Energy Limited"
#     },
#     {
#         "id": "alsynite-one-nz-limited",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.alsynite.co.nz",
#                 "type": "link",
#                 "url": "http://www.alsynite.co.nz"
#             }
#         ],
#         "title": "Alsynite One NZ Limited"
#     },
#     {
#         "id": "altex-coatings-limited",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.altexcoatings.co.nz",
#                 "type": "link",
#                 "url": "http://www.altexcoatings.co.nz"
#             }
#         ],
#         "title": "Altex Coatings Limited"
#     },
#     {
#         "id": "altherm-joinery-west-auckland-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.althermwest.co.nz",
#                 "type": "link",
#                 "url": "http://www.althermwest.co.nz/"
#             }
#         ],
#         "title": "Altherm Joinery West Auckland Limited"
#     },
#     {
#         "id": "altitude-aerospace-interiors",
#         "secondary_data": [
#             {
#                 "text": "Engineering",
#                 "type": "text"
#             },
#             {
#                 "text": "www.altitude-ai.com",
#                 "type": "link",
#                 "url": "http://www.altitude-ai.com"
#             }
#         ],
#         "title": "Altitude Aerospace Interiors"
#     },
#     {
#         "id": "altitude-resurfacing-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.altituderesurfacing.co.nz",
#                 "type": "link",
#                 "url": "http://www.altituderesurfacing.co.nz"
#             }
#         ],
#         "title": "Altitude Resurfacing Limited"
#     },
#     {
#         "id": "alto-packaging-ltd",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.alto.co.nz",
#                 "type": "link",
#                 "url": "http://www.alto.co.nz"
#             }
#         ],
#         "title": "Alto Packaging Ltd"
#     },
#     {
#         "id": "altus-nz-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "altus.co.nz",
#                 "type": "link",
#                 "url": "http://altus.co.nz/"
#             }
#         ],
#         "title": "Altus NZ Limited"
#     },
#     {
#         "id": "alu-fix-installation-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "WWW.ALUFIX.CO.NZ",
#                 "type": "link",
#                 "url": "http://WWW.ALUFIX.CO.NZ"
#             }
#         ],
#         "title": "Alu Fix Installation Limited"
#     },
#     {
#         "id": "ambience-tiling-ltd",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.ambiencetiling.co.nz",
#                 "type": "link",
#                 "url": "http://www.ambiencetiling.co.nz"
#             }
#         ],
#         "title": "Ambience Tiling Ltd"
#     },
#     {
#         "id": "amcor-flexibles-new-zealand-limited",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.amcor.com",
#                 "type": "link",
#                 "url": "http://www.amcor.com/"
#             }
#         ],
#         "title": "Amcor Flexibles (New Zealand) Limited"
#     },
#     {
#         "id": "aml-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "alliedconcrete.co.nz",
#                 "type": "link",
#                 "url": "http://alliedconcrete.co.nz"
#             }
#         ],
#         "title": "AML Limited"
#     },
#     {
#         "id": "amphenol-phitek-ltd",
#         "secondary_data": [
#             {
#                 "text": "Science & Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "phitek.com",
#                 "type": "link",
#                 "url": "http://phitek.com/"
#             }
#         ],
#         "title": "Amphenol Phitek Ltd"
#     },
#     {
#         "id": "amplifon-nz-limited",
#         "secondary_data": [
#             {
#                 "text": "Healthcare",
#                 "type": "text"
#             },
#             {
#                 "text": "www.bayaudiology.co.nz",
#                 "type": "link",
#                 "url": "http://www.bayaudiology.co.nz"
#             }
#         ],
#         "title": "Amplifon NZ Limited"
#     },
#     {
#         "id": "amuri-dairying-limited",
#         "secondary_data": [
#             {
#                 "text": "Agriculture, Forestry and Fishing",
#                 "type": "text"
#             }
#         ],
#         "title": "Amuri Dairying Limited"
#     },
#     {
#         "id": "andrews-property-services-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.apsltd.co.nz",
#                 "type": "link",
#                 "url": "http://www.apsltd.co.nz"
#             }
#         ],
#         "title": "Andrews Property Services Limited"
#     },
#     {
#         "id": "animates-new-zealand-holdings-limited",
#         "secondary_data": [
#             {
#                 "text": "Retail",
#                 "type": "text"
#             },
#             {
#                 "text": "www.animates.co.nz",
#                 "type": "link",
#                 "url": "http://www.animates.co.nz"
#             }
#         ],
#         "title": "Animates New Zealand Holdings Limited"
#     },
#     {
#         "id": "anz-bank-new-zealand-limited",
#         "secondary_data": [
#             {
#                 "text": "Accounting, Finance & Legal",
#                 "type": "text"
#             },
#             {
#                 "text": "www.anz.co.nz",
#                 "type": "link",
#                 "url": "http://www.anz.co.nz"
#             }
#         ],
#         "title": "ANZ Bank New Zealand Limited"
#     },
#     {
#         "id": "aotea-electric-auckland-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aoteaelectric.co.nz",
#                 "type": "link",
#                 "url": "http://www.aoteaelectric.co.nz/"
#             }
#         ],
#         "title": "Aotea Electric Auckland Limited"
#     },
#     {
#         "id": "aotea-electric-queenstown-limited",
#         "secondary_data": [
#             {
#                 "text": "Other",
#                 "type": "text"
#             }
#         ],
#         "title": "Aotea Electric Queenstown Limited"
#     },
#     {
#         "id": "aotea-security-nz-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aoteasecurity.co.nz",
#                 "type": "link",
#                 "url": "http://www.aoteasecurity.co.nz"
#             }
#         ],
#         "title": "Aotea Security (NZ) Limited"
#     },
#     {
#         "id": "ap-hydraulics-limited",
#         "secondary_data": [
#             {
#                 "text": "Engineering",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aphydraulics.co.nz",
#                 "type": "link",
#                 "url": "http://www.aphydraulics.co.nz"
#             }
#         ],
#         "title": "AP Hydraulics Limited"
#     },
#     {
#         "id": "apex-airconditioning-limited",
#         "secondary_data": [
#             {
#                 "text": "Other",
#                 "type": "text"
#             },
#             {
#                 "text": "www.apexair.co.nz",
#                 "type": "link",
#                 "url": "http://www.apexair.co.nz"
#             }
#         ],
#         "title": "Apex Airconditioning Limited"
#     },
#     {
#         "id": "api-talent-limited",
#         "secondary_data": [
#             {
#                 "text": "Information Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "www.apitalent.co.nz",
#                 "type": "link",
#                 "url": "http://www.apitalent.co.nz"
#             }
#         ],
#         "title": "API Talent Limited"
#     },
#     {
#         "id": "apl-kwikform-pty-limited-ta-united-scaffolding",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "aplkwikform.co.nz",
#                 "type": "link",
#                 "url": "http://aplkwikform.co.nz/"
#             }
#         ],
#         "title": "Apl Kwikform Pty Limited Ta United Scaffolding"
#     },
#     {
#         "id": "apple-technology-services",
#         "secondary_data": [
#             {
#                 "text": "Information Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "www.apple.com",
#                 "type": "link",
#                 "url": "http://www.apple.com/nz/"
#             }
#         ],
#         "title": "Apple Technology Services"
#     },
#     {
#         "id": "applied-conveyor-polymers-ltd",
#         "secondary_data": [
#             {
#                 "text": "Manufacturing",
#                 "type": "text"
#             },
#             {
#                 "text": "www.appliedconveyor.co.nz",
#                 "type": "link",
#                 "url": "http://www.appliedconveyor.co.nz/"
#             }
#         ],
#         "title": "Applied Conveyor & Polymers Ltd"
#     },
#     {
#         "id": "aquaheat-facility-services-limited",
#         "secondary_data": [
#             {
#                 "text": "Water, Gas, Electricity",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aquaheat.co.nz",
#                 "type": "link",
#                 "url": "http://www.aquaheat.co.nz"
#             }
#         ],
#         "title": "Aquaheat Facility Services Limited"
#     },
#     {
#         "id": "aquaheat-new-zealand-ltd",
#         "secondary_data": [
#             {
#                 "text": "Water, Gas, Electricity",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aquaheat.co.nz",
#                 "type": "link",
#                 "url": "http://www.aquaheat.co.nz"
#             }
#         ],
#         "title": "Aquaheat New Zealand Ltd"
#     },
#     {
#         "id": "ara-institute-of-canterbury",
#         "secondary_data": [
#             {
#                 "text": "Education & Training",
#                 "type": "text"
#             },
#             {
#                 "text": "www.ara.ac.nz",
#                 "type": "link",
#                 "url": "http://www.ara.ac.nz/"
#             }
#         ],
#         "title": "Ara Institute of Canterbury"
#     },
#     {
#         "id": "aranz-geo-limited",
#         "secondary_data": [
#             {
#                 "text": "Information Technology",
#                 "type": "text"
#             },
#             {
#                 "text": "www.aranzgeo.com",
#                 "type": "link",
#                 "url": "http://www.aranzgeo.com"
#             }
#         ],
#         "title": "ARANZ GEO Limited"
#     },
#     {
#         "id": "archibald-shorter-roverland-limited",
#         "secondary_data": [
#             {
#                 "text": "Retail",
#                 "type": "text"
#             },
#             {
#                 "text": "www.archibaldandshorter.co.nz",
#                 "type": "link",
#                 "url": "http://www.archibaldandshorter.co.nz"
#             }
#         ],
#         "title": "Archibald & Shorter Roverland Limited "
#     },
#     {
#         "id": "archibalds-motors-limited",
#         "secondary_data": [
#             {
#                 "text": "Retail",
#                 "type": "text"
#             },
#             {
#                 "text": "www.archibalds.co.nz",
#                 "type": "link",
#                 "url": "http://www.archibalds.co.nz"
#             }
#         ],
#         "title": "Archibalds Motors Limited"
#     },
#     {
#         "id": "architectural-metalformers-ltd",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             },
#             {
#                 "text": "www.archform.co.nz",
#                 "type": "link",
#                 "url": "http://www.archform.co.nz"
#             }
#         ],
#         "title": "Architectural Metalformers Ltd"
#     },
#     {
#         "id": "architectural-window-solutions-limited",
#         "secondary_data": [
#             {
#                 "text": "Construction & Building",
#                 "type": "text"
#             }
#         ],
#         "title": "Architectural Window Solutions Limited"
#     },
#     {
#         "id": "argenta-manufacturing-limited",
# ...
#
#                                 <option value="https://www.immigration.govt.nz/audiences/supporting-refugees-and-asylum-seekers">Refugees, asylum seekers and their families</option>
#
#                         </select>
#                     </div>
#                 </div>
#                 <div class="col-lg-6">
#                     <div class="dropdown__footer right js-follow">
#                         <label class="dropdown_label__footer" for="footer_factsheet">Find a visa factsheet</label>
#                         <select id="footer_factsheet" autocomplete="off" data-maxselection="1" class="js-select2 js-select2-theme_dark dropdown_body__footer right" title="e.g. visitor visa, skilled migrant..." style="width: 100%" data-placeholder="e.g. visitor visa, skilled migrant..." data-minimuminputlength="2" data-ajax-url="https://www.immigration.govt.nz/factsheet_search">
#                         </select>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#     <div class="footer_primary">
#         <div class="wrapper">
#             <div class="row">
#
# 	                <div class="footer_primary_col footer_primary_col__first clearfix">
#                         <p class="footer_list__header">
# 	                    	<a href="https://www.immigration.govt.nz/new-zealand-visas">New Zealand visas</a>
#                             <span class="footer_list_link__slide_trigger" data-target="#new-zealand-visas"></span>
#                         </p>
# 	                    <ul class="footer_list" id="new-zealand-visas-footeritem">
# 	                    	<li><a href="https://www.immigration.govt.nz/resolveuid/c5078a920a304cf8b8a728aa59cfce1d"><span>Explore NZ visa options</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/new-zealand-visas/apply-for-a-visa"><span>Apply for a visa</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/new-zealand-visas/waiting-for-a-visa"><span>Waiting for a visa</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/new-zealand-visas/already-have-a-visa"><span>Already have a visa</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/resolveuid/dff5222864f94187a869e38cd3b0a8cf"><span>Application forms, guides and checklists</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/resolveuid/6fa59538acfb4c879a471a2cdbb49faf"><span>How to get a police certificate</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/resolveuid/866dcabea1574ec98d5dd8d0ba8d9f68"><span>Find a doctor or radiologist</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/resolveuid/102c1d707fa94170b4e88c6ec74878f4"><span>Fees, decision times and where to apply</span></a></li>
# 	                    </ul>
# 	                </div>
#
# 	                <div class="footer_primary_col">
#                         <p class="footer_list__header">
# 	                    	<a href="https://www.immigration.govt.nz/employ-migrants">Employ migrants</a>
#                             <span class="footer_list_link__slide_trigger" data-target="#employ-migrants"></span>
#                         </p>
# 	                    <ul class="footer_list" id="employ-migrants-footeritem">
# 	                    	<li><a href="https://www.immigration.govt.nz/employ-migrants/explore-your-options"><span>Explore your options</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/employ-migrants/hire-a-candidate"><span>Hire a candidate</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/employ-migrants/settle-migrant-staff"><span>Settle migrant staff</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/resolveuid/9c5cfb9a3773488b86870c845fcae728"><span>VisaView for employers</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/employ-migrants/guides"><span>Employer guides</span></a></li>
# 	                    </ul>
# 	                </div>
#
# 	                <div class="footer_primary_col">
#                         <p class="footer_list__header">
# 	                    	<a href="https://www.immigration.govt.nz/assist-migrants-and-students">Assist migrants and students</a>
#                             <span class="footer_list_link__slide_trigger" data-target="#assist-migrants-and-students"></span>
#                         </p>
# 	                    <ul class="footer_list" id="assist-migrants-and-students-footeritem">
# 	                    	<li><a href="https://www.immigration.govt.nz/assist-migrants-and-students/assist-students"><span>Assist students</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/assist-migrants-and-students/assist-refugees"><span>Assist refugees</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/resolveuid/5c5afb69285c4005a5fe004ef8a1ceaf"><span>Information for medical professionals</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/assist-migrants-and-students/other-industry-partners"><span>Other industry partners</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/resolveuid/068de535af51415c9b38e2aca8a7ef92"><span>Student enrolment termination form</span></a></li>
# 	                    </ul>
# 	                </div>
#
# 	                <div class="footer_primary_col">
#                         <p class="footer_list__header">
# 	                    	<a href="https://www.immigration.govt.nz/about-us">About us</a>
#                             <span class="footer_list_link__slide_trigger" data-target="#about-us"></span>
#                         </p>
# 	                    <ul class="footer_list" id="about-us-footeritem">
# 	                    	<li><a href="https://www.immigration.govt.nz/about-us/policy-and-law"><span>Policy and law</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/about-us/what-we-do"><span>What we do</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/about-us/media-centre"><span>News centre</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/about-us/resource-library"><span>Resource Library</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/about-us/research-and-statistics"><span>Research and statistics</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/about-us/our-online-systems"><span>Our online systems</span></a></li>
# 	                    </ul>
# 	                </div>
#
# 	                <div class="footer_primary_col footer_primary_col__last">
#                         <p class="footer_list__header">
# 	                    	<a href="https://www.immigration.govt.nz/contact">Contact us</a>
#                             <span class="footer_list_link__slide_trigger" data-target="#contact"></span>
#                         </p>
# 	                    <ul class="footer_list" id="contact-footeritem">
# 	                    	<li><a href="https://www.immigration.govt.nz/resolveuid/619005941864496fb9a2c1d9689cd07e"><span>Talk to us</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/resolveuid/5770d636cece4b5e82693d962c6ba012"><span>Visa processing times</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/contact/complaints"><span>Make a complaint</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/contact/report-fraud"><span>Report an offence</span></a></li>
#                       <li><a href="https://www.immigration.govt.nz/contact/request-information"><span>Request or change your personal information</span></a></li>
#                       <li><a href="https://nzeta.immigration.govt.nz/check-status" class="link_external link_external_footer" target="_blank"><span>Check your NZeTA status</span></a></li>
# 	                    </ul>
# 	                </div>
#
#
#             </div>
#         </div>
#     </div>
#     <div class="footer_secondary">
#         <div class="wrapper wrapper__medium">
#             <div class="row ">
#                 <div class="col-md-6">
#                     <a href="http://mbie.govt.nz" class="mbie_logo">Ministry of Business, Innovation, &amp; Employment</a>
#                 </div>
#                 <div class="col-md-6">
#                     <a href="https://www.govt.nz/" class="nzgovt_logo">New Zealand Government</a>
#                 </div>
#             </div>
#         </div>
#     </div>
#     <div class="footer_tertiary">
#         <div class="wrapper wrapper__medium">
#             <div class="row">
#                 <div class="col-md-6">
#                     <ul class="footer_tertiary_list">
#                         <li class="f_tertiary_text"><a href="https://www.immigration.govt.nz/about-us/site-information/glossary"><span>Glossary</span></a></li>
#                         <li class="f_tertiary_text"><a href="https://www.immigration.govt.nz/about-us/site-information/accessibility"><span>Accessibility</span></a></li>
#                         <li class="f_tertiary_text"><a href="https://www.immigration.govt.nz/about-us/site-information/privacy"><span>Privacy</span></a></li>
#                         <li class="f_tertiary_text"><a href="https://www.immigration.govt.nz/about-us/site-information/copyright"><span>Copyright</span></a></li>
#                         <li class="f_tertiary_text"><a href="https://www.immigration.govt.nz/about-us/site-information/terms-of-use"><span>Terms of use</span></a></li>
#                         <li class="f_tertiary_text"><a href="https://www.immigration.govt.nz/cookie-preferences"><span>Cookie Preferences</span></a></li>
#
#
#                     </ul>
#                 </div>
#                 <div class="col-md-6">
#                     <p class="f_tertiary_text f_tertiary_text__c">© 2020 Immigration New Zealand</p>
#                 </div>
#             </div>
#         </div>
#     </div>
# </footer>
#
#
# <!-- include('../../includes/photoswipe.php'); -->
#
# <!-- Root element of PhotoSwipe. Must have class pswp. /-->
# <div class="pswp photoswipe" tabindex="0" role="dialog" aria-hidden="true">
#     <div class="pswp__bg"></div>
#     <div class="pswp__scroll-wrap">
#         <div class="pswp__container">
#             <div class="pswp__item"></div>
#             <div class="pswp__item"></div>
#             <div class="pswp__item"></div>
#         </div>
#
#         <div class="pswp__ui pswp__ui--hidden">
#             <div class="pswp__top-bar">
#                 <div class="pswp__counter"></div>
#                 <button class="pswp__button pswp__button--close glyph_cross" title="Close (Esc)">
#                     <span class="sr-only">Close</span>
#                 </button>
#                 <button class="pswp__button pswp__button--share glyph_social" title="Share">
#                     <span class="sr-only">Share</span>
#                 </button>
#                 <button class="pswp__button pswp__button--fs glyph_fullscreen" title="Toggle fullscreen">
#                     <span class="sr-only">Toggle fullscreen</span>
#                 </button>
#                 <button class="pswp__button pswp__button--zoom glyph_zoom-in" title="Zoom in/out">
#                     <span class="sr-only">Zoom in/out</span>
#                 </button>
#
#                 <!-- Preloader demo http://codepen.io/dimsemenov/pen/yyBWoR /-->
#                 <!-- element will get class pswp__preloader- -active when preloader is running /-->
#                 <div class="pswp__preloader">
#                     <div class="pswp__preloader__icn">
#                       <div class="pswp__preloader__cut">
#                         <div class="pswp__preloader__donut"></div>
#                       </div>
#                     </div>
#                 </div>
#             </div>
#
#             <div class="pswp__share-modal pswp__share-modal--hidden pswp__single-tap">
#                 <div class="pswp__share-tooltip"></div>
#             </div>
#
#             <button class="pswp__button pswp__button--arrow--left" title="Previous (arrow left)">
#             </button>
#
#             <button class="pswp__button pswp__button--arrow--right" title="Next (arrow right)">
#             </button>
#
#             <div class="pswp__caption">
#                 <div class="pswp__caption__center"></div>
#             </div>
#
#         </div>
#
#     </div>
#
# </div>
#
#
# <!-- include('../../includes/foot.php'); -->
#
# <div class="container_shader"><!-- /--></div>
# <!-- /div-->
# <!-- end of main_div /-->
#
# <p class="footer__print_date">Information updated on 2019/06/28 13:06:52.885129 GMT+12</p>
#
# <section id="docked_sliding_panel" class="dock closed">
# 	<div class="dock_dialog">
# 		<div class="dock_content">
# 			<div class="dock_tools tools">
# 				<button class="tools_close btn btn__primary" data-dismiss="dock">
# 					<span class="glyph_cross"></span>
# 					<span class="sr-only">Close</span>
# 				</button>
#
#
#
# 				<div class="tools_secondary">
# 					<!-- <span class="tools_lang btn js-temp" data-toggle>
# 						<button class="tools_btn btn btn__info">
# 							<span class="glyph">语言</span>
# 						</button>
# 						<span class="title switches js-contain">
# 							<a href="#english" class="switch-1 tools_option active" data-toggle data-switch-off=".switch-2">
# 								English
# 							</a>
# 							<a href="#中国" class="switch-2 tools_option" data-toggle data-switch-off=".switch-1">
# 								中国
# 							</a>
# 						</span>
# 					</span> -->
# 					<button class="tools_print btn btn__secondary js-temp" data-action="print">
# 						<span class="glyph_print"></span>
# 						<span class="title">Print</span>
# 					</button>
#
# 				</div>
#
#
#
# 			</div>
# 			<div class="dock_body" tabindex="0">
# 				<div class="dock_bodywrap content" data-toggle-switch-watch="">
#
# 				</div>
#
#
# 			</div>
# 		</div>
# 	</div>
#
# </section>
#
#
# <script>
# 	var inz = inz || {};
#
# 	inz.pageTools = {
# 		downloadFile: function() {
# 			// return a file to the user to download
#
# 			// ****** NOTE: still waiting on function implementation from front-end dev team ******
# 		}
# 	};
# </script>
#
# <iframe id="print_dock" title="Iframe used to assist printing" tabindex="-1" src="about:blank" style="display:none; height:500px; width:150%">
# </iframe>
#
# <!-- script moved to app_simple template -->
# <!-- dev, seperate files for debugging /-->
# <!-- script src="../../js/dist/site.src.js"></script-->
#
# <!-- production, not ready for use yet /-->
# <!--<script src="/js/site.min.js"></script>-->
#
#
#
# </div>
# <!-- end of main_div /-->
#
#
#       <script id="site_messages_data" type="text/javascript" src="/site-messages.js"></script>
# <script type="text/javascript">
#     var JS_VENDOR_LOCATION = 'https://www.immigration.govt.nz/++resource++inz.static.27/vendor/';
#     var IMAGES_LOCATION = 'https://www.immigration.govt.nz/++resource++inz.static.27/images/';
#     var CSS_LOCATION = 'https://www.immigration.govt.nz/++resource++inz.static.27/';
# </script>
# <script type="text/javascript" src="https://www.immigration.govt.nz/++resource++inz.static.27/site.src.js"></script>
#
#
#
# <script type="text/javascript" src="https://www.immigration.govt.nz/cookie-consent.js"></script>
# <script type="text/javascript">
#     if(typeof(inz.cookieConsent)!=='undefined')
#     {
#         $(document).ready(function()
#         {
#             inz.cookieConsent.bannerCheck();
#         });
#     }
# </script>
#
#
# <script type="text/javascript" src="https://www.immigration.govt.nz/js/cms-121.03/inz.js"></script>
# <script type="text/javascript" src="/++resource++inz.site/js.cookie.min.js?r=cms-121.03"></script>
# <script type="text/javascript">
# //<![CDATA[
#     inz.geoip_webservice_url = '//geoip.tungstenweb.com/json/';
#     inz.varyContentByLocation();
# 	inz.siteSearch.state.url = 'https://www.immigration.govt.nz/search';
# //]]></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# </body>
#
# </html>

# %%
import re

text = '"secondary_data": .*?"url": "(.*?)"'
info = re.finditer(text, res, re.S)

address = []
industry = []
for i in info:
    desc = re.findall('"text": "(.*?)"', i.group(0), re.S)
    address.append(desc[1])
    industry.append(desc[0])
print(address)
print(industry)
# Out:
# ['www.8i.com', 'www.180degrees.org.nz', 'Other', 'Agriculture, Forestry and Fishing', 'www.foleys.co.nz', 'www.verkerks.co.nz', 'www.trinder.co.nz', 'www.a-ward.com', 'www.wilcoxgoodness.co.nz', 'www.kiwicutters.co.nz', 'www.aainsurance.co.nz', 'www.accorhotels.com', 'www.abequipment.co.nz', 'www.abb.co.nz', 'www.abbotts.co.nz', 'www.abley.com', 'www.absoluteit.co.nz', 'www.accenture.co.nz', 'www.accesssolutions.co.nz', 'www.acciona.com', 'www.acgedu.com', 'www.o-i.com', 'www.acrow.co.nz', 'www.activecontracting.co.nz', 'www.adecco.co.nz', 'www.adeptgroup.co.nz', 'www.adtsecurity.co.nz', 'www.asgl.co.nz', 'www.asgl.co.nz', 'www.aecom.com', 'www.aero.net.nz', 'www.afcnz.com', 'www.agbstone.co.nz', 'www.affordablescaffolding.co.nz', 'www.agcnetworks.com', 'www.agilitycis.com', 'www.agilyxgroup.co.nz', 'agnewtransport.co.nz', 'www.agresearch.co.nz', 'www.aia.co.nz', 'www.aig.com', 'www.aimex.co.nz', 'www.AirMarkGroup.co', 'www.airnewzealand.co.nz', 'www.airtight.co.nz', 'www.airways.co.nz', 'www.airwork.co.nz', 'www.mairangibay.laserplumbing.co.nz', 'alexaderconstructioncentral.co.nz', 'freshchoice.co.nz', 'www.alleuroparts.co.nz', 'www.allinonebuilders.co.nz', 'www.allseasonsair.co.nz', 'www.advancedpumping.nz', 'www.allegisgroup.com', 'allfields.co.nz', 'www.allianceservices.co.nz', 'www.alliedpetroleum.co.nz', 'www.alloycats.co.nz', 'www.allstarbuilder.co.nz', 'alphagroup.nz', 'www.alphajobs.co.nz', 'www.alpineenergy.co.nz', 'www.alsynite.co.nz', 'www.altexcoatings.co.nz', 'www.althermwest.co.nz', 'www.altitude-ai.com', 'www.altituderesurfacing.co.nz', 'www.alto.co.nz', 'altus.co.nz', 'WWW.ALUFIX.CO.NZ', 'www.ambiencetiling.co.nz', 'www.amcor.com', 'alliedconcrete.co.nz', 'phitek.com', 'www.bayaudiology.co.nz', 'Construction & Building', 'www.animates.co.nz', 'www.anz.co.nz', 'www.aoteaelectric.co.nz', 'Construction & Building', 'www.aphydraulics.co.nz', 'www.apexair.co.nz', 'www.apitalent.co.nz', 'aplkwikform.co.nz', 'www.apple.com', 'www.appliedconveyor.co.nz', 'www.aquaheat.co.nz', 'www.aquaheat.co.nz', 'www.ara.ac.nz', 'www.aranzgeo.com', 'www.archibaldandshorter.co.nz', 'www.archibalds.co.nz', 'www.archform.co.nz', 'Manufacturing', 'www.argusfire.co.nz', 'www.armitagegrp.com', 'www.armstrongmotorsgroup.com', 'www.armstrongmotorgroup.com', 'www.armstrongmotorgroup.com', 'www.arrowinternational.co.nz', 'artrix.com', 'www.arup.com', 'www.asaleo.com', 'www.asb.co.nz', 'www.asbestosnz.com', 'Other', 'www.asphaltech.co.nz', 'www.assaabloy.co.nz', 'assurity.co.nz', 'www.asurequality.com', 'atlgroup.co.nz', 'www.atlasconcrete.co.nz', 'www.atlascopco.com', 'www.atraxgroup.com', 'aucklandairport.co.nz', 'www.ahgnz.co.nz', 'www.teambmw.com', 'www.aucklandcouncil.govt.nz', 'www.adhb.govt.nz', 'www.aa.co.nz', 'www.aucklandeye.co.nz', 'www.aucklandairport.co.nz', 'aucklandpanel.co.nz', 'aucklandplumbersgroup.nz', 'www.aucklandnz.com', 'www.aucklandtransport.govt.nz', 'www.uniservices.co.nz', 'www.aut.ac.nz', 'www.jasmax.com', 'www.aurecongroup.com', 'Engineering', 'autotransform.co.nz', 'www.aviatnetworks.com', 'www.bgcontracting.co.nz', 'Engineering', 'babichwines.co.nz', 'www.bakerhughes.com', 'www.balcrom.co.nz', 'www.ballance.co.nz', 'www.bnzcareers.co.nz', 'www.barbershop.co.nz', 'Construction & Building', 'www.baxter.co.nz', 'www.bayswatervehicles.co.nz', 'bdo.nz', 'beattys.co.nz', 'www.beca.com', 'www.beca.com', 'www.beca.com', 'www.beca.com', 'Agriculture, Forestry and Fishing', 'www.bellgully.com', 'Construction & Building', 'Transport & Logistics', 'www.Beyondrecruitment.co.nz', 'www.bidvest.co.nz', 'www.bigchill.co.nz', 'www.birthcare.co.nz', 'www.blairwright.co.nz', 'www.bluebarn.co.nz', 'www.getbluelab.com', 'Accounting, Finance & Legal', 'www.bmw.co.nz', 'www.sdv.com', 'www.bowersconcrete.co.nz', 'dittmer.co.nz', 'www.brambles.com', 'www.brazier.co.nz', 'brendanfoot.co.nz', 'www.aluminiumjoineryhamilton.co.nz', 'www.holgatepanel.co.nz', 'Manufacturing', 'www.bspb.co.nz', 'www.bridon.co.nz', 'www.broadspectrum.com', 'www.b ...
# ['Digital Media', 'Education & Training', 'Agriculture, Forestry and Fishing', 'Agriculture, Forestry and Fishing', 'Water, Gas, Electricity', 'Food and Beverages Manufacturing', 'Manufacturing', 'Transport & Logistics', 'Agriculture, Forestry and Fishing', 'Construction & Building', 'Accounting, Finance & Legal', 'Hospitality & Tourism', 'Construction & Building', 'Engineering', 'Construction & Building', 'Engineering', 'Human Resources', 'Information Technology', 'Construction & Building', 'Construction & Building', 'Education & Training', 'Manufacturing', 'Construction & Building', 'Construction & Building', 'Recruitment', 'Information Technology', 'Other', 'Construction & Building', 'Construction & Building', 'Engineering', 'Construction & Building', 'Administration & Customer Service', 'Construction & Building', 'Construction & Building', 'Telecommunications', 'Information Technology', 'Information Technology', 'Transport & Logistics', 'Agriculture, Forestry and Fishing', 'Accounting, Finance & Legal', 'Accounting, Finance & Legal', 'Manufacturing', 'Engineering', 'Administration & Customer Service', 'Science & Technology', 'Government (central)', 'Engineering', 'Construction & Building', 'Construction & Building', 'Retail', 'Manufacturing', 'Construction & Building', 'Construction & Building', 'Construction & Building', 'Human Resources', 'Information Technology', 'Construction & Building', 'Water, Gas, Electricity', 'High Value Manufacturing', 'Construction & Building', 'Manufacturing', 'Recruitment', 'Water, Gas, Electricity', 'Manufacturing', 'Manufacturing', 'Construction & Building', 'Engineering', 'Construction & Building', 'Manufacturing', 'Construction & Building', 'Construction & Building', 'Construction & Building', 'Manufacturing', 'Construction & Building', 'Science & Technology', 'Healthcare', 'Agriculture, Forestry and Fishing', 'Retail', 'Accounting, Finance & Legal', 'Construction & Building', 'Other', 'Engineering', 'Other', 'Information Technology', 'Construction & Building', 'Information Technology', 'Manufacturing', 'Water, Gas, Electricity', 'Water, Gas, Electricity', 'Education & Training', 'Information Technology', 'Retail', 'Retail', 'Construction & Building', 'Construction & Building', 'Engineering', 'Construction & Building', 'Retail', 'Retail', 'Retail', 'Construction & Building', 'Information Technology', 'Engineering', 'Manufacturing', 'Accounting, Finance & Legal', 'Construction & Building', 'Retail', 'Construction & Building', 'High Value Manufacturing', 'Information Technology', 'Biotechnology', 'Healthcare', 'Manufacturing', 'Other', 'Manufacturing', 'Transport & Logistics', 'Transport & Logistics', 'Retail', 'Government (local)', 'Healthcare', 'Retail', 'Healthcare', 'Hospitality & Tourism', 'Engineering', 'Construction & Building', 'Government (local)', 'Government (local)', 'Education & Training', 'Education & Training', 'Construction & Building', 'Engineering', 'Manufacturing', 'Manufacturing', 'Telecommunications', 'Construction & Building', 'Agriculture, Forestry and Fishing', 'Agriculture, Forestry and Fishing', 'Water, Gas, Electricity', 'Construction & Building', 'High Value Manufacturing', 'Accounting, Finance & Legal', 'Other', 'Construction & Building', 'Healthcare', 'Retail', 'Accounting, Finance & Legal', 'Manufacturing', 'Engineering', 'Engineering', 'Engineering', 'Engineering', 'Other', 'Accounting, Finance & Legal', 'Construction & Building', 'Construction & Building', 'Recruitment', 'Transport & Logistics', 'Transport & Logistics', 'Healthcare', 'Manufacturing', 'Engineering', 'High Value Manufacturing', 'Construction & Building', 'Retail', 'Transport & Logistics', 'Manufacturing', 'Other', 'Transport & Logistics', 'Construction & Building', 'Retail', 'Manufacturing', 'Transport & Logistics', 'Manufacturing', 'Other', 'Manufacturing', 'Engineering', 'Agriculture, Forestry and Fishing', 'Construction & Building', 'Construction & Building', 'Agriculture, Forestry and Fish ...

# %%
import pandas as pd
import os

structure = pd.DataFrame()
structure['Address'] = address
structure['Industry'] = industry
if not os.path.exists('companies.xlsx'):
    structure.to_excel('companies.xlsx')

# %%
import xlwings as xw
import webbrowser
app = xw.App(visible=False)
wb = app.books.open('companies.xlsx')
sht = wb.sheets['Sheet2']

for cell in sht.range('B2:B3'):
    webbrowser.open(cell.value, new=2, autoraise=True)
wb.close()
app.quit()

# %%
import webbrowser
for i in range(10):
    webbrowser.open(info[i], new=2, autoraise=True)
